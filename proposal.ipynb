# %% [markdown]
# # CS 449 Final Project Proposal
#
# Due: February 1, 2023 at 11:59pm
#
# ## 1. Names and Net IDs
#
# Dennis Wu: YWL7940
#
# Will Wu: JWX6086
#
# Guandi Wang: GWG5776
#
# Ian Cramer: IMC839
#
# Uzair Qadir: UMQ7573
#
# ## 2. Abstract
#
# Our final project seeks to use a variety of deep neural networks to Detect Covid-19 through X-ray images of patients. We will compare models such as CNN based different backbone like VGG, ResNet, GoogleNet, and visual transformer (ideally)

# %% [markdown]
# ## 3. Introduction
#
# As machine learning has became an essential tool for image recognition, many of the methods was also used in medical related tasks such as cancer detection, X-ray classficiation, image superesolution, etc.
#
# Meanwhile, covid has been a critical issue in medical/public health domain since 2020. While covid itself and its adaptation gets more common, an automatic tool to identify whether a patient is covid-positive is necessary. Such tool will greatly reduce the medical labor cost and further improve the efficiency of covid-related researches.
#
# In this project, we aim to test different popular image recognition models such as VGG, ResNet, GoogleNet or even visual transformer on the covid-19 detection dataset on kaggle. This dataset contains the chest X-rays of different patients, and our goal is to correctly classify whether this person has covid given his/her chest X-ray. We expect to obtain a conclusion that which common model is more suitable for such task, and also try to provide explanations on it.

# %% [markdown]
# ## 4a. Describe your dataset(s)
#
# We found a covid-19 x-ray dataset from Kaggle with the following link:
# https://www.kaggle.com/datasets/manishkc06/covid19-detection
#
# The dataset contains image data of 3479 jpgs, each image is 390 pixel by 320 pixel. The annotation is stored in a csv file, where it contains two columns where the first one is the names of each images, and the second one is the ground truth value for covid-19 detection (0 stands for negative, no coivd-19 detected, and 1 stands for positive).
#
# This dataset is very popular. There are 586 citations.

# %%
## 4b. Show some data
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# A visualization of two selected images

img1_path = "/content/sample_data/Image_100.jpg"
img2_path = "/content/sample_data/Image_1000.jpg"

img1 = mpimg.imread(img1_path)
img2 = mpimg.imread(img2_path)
imgplot = plt.imshow(img1)
plt.show()
imgplot = plt.imshow(img2)
plt.show()

# %% [markdown]
# ## 5. Methods
#
# *Describe what methods you plan to use. Give a one or two sentence history of how and when these methods were developed, and be sure to cite relevant papers. What kind of neural network architectures will you use? What loss function(s) will you use and why? How will you evaluate your model's ability to generalize to new data? For example:*
#
# This is a standard supervised learning task, and we plan to train our data on different types of deep neural network, compare and  analyse different results.
# The first one is ResNet, proposed in "Deep Residual Learning for Image Recognition" in 2015. It is a originally designed for object detection tasks such as COCO object detection dataset. But it is also widely used nowadays for transfer learning for other upstream machine learning stasks.
#
# The second one is VGG, propsed in "Very Deep Convolutional Networks for Large-Scale Image Recognition" in 2014. This is another CNN based deep learning network architecture that was motivated by "the deeper the networks, the better the results". It is also widely used nowadays for transfer learning for other upstream machine learning stasks.
#
# The third one is vision transformer, proposed in "An image is worth 16x16 words: Transformers for image recognition at scale", it follows the attention mechanism that was commonly used in natural language processing task. It split an image into patches and try to learn not only the representation of each patch, but also the importance of different patch.
# Finally it aggregate all of the weighted representation generated from patches, and send it to the classifier layer for classification.
#
# For our detection tasks, we will use cross-entropy loss to monitor our traning and classification accuracy to measure the performance of our model.

# %% [markdown]
# ### 6.1 Essential Goals
# - We will implement at least 3 types of neural network structures for image recognition.
# - We will include data augmentation methods to the training algorithm to improve model performance.
#
# ### 6.2 Desired Goals
# - We will conduct a thorough comparative study on how different neural network architectures work on this covid-19 dataset. And try to find a explanation on why.
# - We will also analyze on training time complexity of different models and try to see which model is more "time efficient", or has a better tradeoff on training time and performance.
#
# ### 6.3 Stretch Goals
# - We will include more related chest X-ray data for pretraining and see if it will improve model generalization.
# - We will incoporrate with self-supervised learning to achieve data efficient pretraining.

# %% [markdown]
# ## 7. Hopes and Concerns
#
# We are excited to see the performance of each DNN on this selected datasets. We are worried that our dataset has relative small size comparing to those powerful DNN with huge capacity like VGG and transformer. We are worried about if this can lead to satisfying results.

# %% [markdown]
# ## 8. References
#
# He, Kaiming, et al. "Deep residual learning for image recognition." Proceedings of the IEEE conference on computer vision and pattern recognition. 2016.
#
# Simonyan, Karen, and Andrew Zisserman. "Very deep convolutional networks for large-scale image recognition." arXiv preprint arXiv:1409.1556 (2014).
#
# Dosovitskiy, Alexey, et al. "An image is worth 16x16 words: Transformers for image recognition at scale." arXiv preprint arXiv:2010.11929 (2020).
#
# Guefrechi S, Jabra MB, Ammar A, Koubaa A, Hamam H. Deep learning based detection of COVID-19 from chest X-ray images. Multimed Tools Appl. 2021;80(21-23):31803-31820. doi: 10.1007/s11042-021-11192-5. Epub 2021 Jul 19. PMID: 34305440; PMCID: PMC8286881.
#
# Cohen, Joseph Paul, et al. "Covid-19 image data collection: Prospective predictions are the future." arXiv preprint arXiv:2006.11988 (2020).
